# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading data
# https://archive.ics.uci.edu/ml/datasets/glass+identification
filename = 'glass.csv'
dataset = pd.read_csv(filename)

# %%
print(dataset)
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
# How many datapoints is missing?
dataset.notnull().sum(axis=0)

# 214 corresponds to the number of rows! We are happy!
# Out:
# ID      214
# RI      214
# Na      214
# Mg      214
# Al      214
# Si      214
# K       214
# Ca      214
# Ba      214
# Fe      214
# Type    214
# dtype: int64

# %% [markdown]
# Standardization (copied from PCA)

# %%
data = dataset.iloc[:,1:-1]
mean_vals, std_vals = np.mean(data,axis=0), np.std(data)
stand_data = (data - mean_vals)/std_vals
stand_data.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1 -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2 -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3 -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4 -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
#
#          Ba        Fe
# 0 -0.352877 -0.586451
# 1 -0.352877 -0.586451
# 2 -0.352877 -0.586451
# 3 -0.352877 -0.586451
# 4 -0.352877 -0.586451

# %% [markdown]
# **Are there any outliers?**
#
# Plotting the boxplots

# %%
fig, ax = plt.subplots(2,5)
j = 0
for i in range(9):
    if i == 5: j = 1
    if i >= 5: i = i - 5

    temp = stand_data.iloc[:,i]

    ax[j,i].boxplot(temp)

fig.set_size_inches(18.5, 10.5)
fig.show()
    
# there are many outliers if we use the boxplots
# Out:
# /var/folders/k7/4m0jgf1s5rggf6q996sfswf00000gn/T/ipykernel_53626/761548104.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Conclusion?
#
# The boxplot criteria for an outlier is unapplicable in our case.
